# %% [markdown]
# # UAS AMS
# - Nama  : Gilbert Kenanya El Sarun
# - NIM   : A12.2020.06330
# - Kelas : A12.6502
# # Prediksi Pertandingan *EPL* dengan Metode Random Forest dan Rolling Averages
#
# # Latar Belakang :
# Tingkat minat masyarakat pada sepak bola saat ini sedang meningkat sangat tajam, hal ini dikarenakan baru selesainya pagelaran sepak bola terbesar yaitu Piala Dunia. Sehingga euforia masyarakat terhadap pertandingan sepak bola sangatlah tinggi. Tidak terlepas pula dari *EPL (English Premiere League)*, hal ini dikarenakan EPL merupakan sebuah pagelaran sepak bola yang bertabur klub – klub besar serta pemain bintang. Dalam menanggapi arus ini saya memilih menjadikan EPL menjadi object penelitian saya, karena EPL merupakan ajang sepak bola yang paling disorot setelah piala dunia serta memiliki catatan pertandingan yang seru serta hasil yang sulit ditebak oleh sebab itu akan menjadi topik yang menarik untuk memprediksi hasil dari EPL.
#
# # Metode yang Digunakan :
# Dalam melakukan percobaan ini saya menggunakan 2 metode sekaligus yaitu Random Forest serta Rolling Averages
#
# **Random Forest**
# Sebuah metode algoritma yang dibangun dari kumpulan pohon keputusan (*Decision Tree*) yang dilatih dengan metode bagging yang mana kombinasi model pembelajaran meningkatkan hasil keseluruhan.
#
# **Rolling Averages**
# Kalkulasi untuk menganalisa point data dengan membuat serangkaian rata rata subset berbeda dari data lengkap.
#
# # Pemodelan
# Pemodelannya menggunakan sistem split dimana data akan dibagi menjadi 2 bagian yaitu data training dan juga Testing
#
# Training (Data sebelum tahun 2022)
# Testing  (Data sesudah tahun 2022)

# %% [markdown]
# # Proses Pengerjaan
# ## Membaca data
# Data yang digunakan adalah data pertandingan *EPL (English Premier League)* Musim ke 2020 dan 2021

# %%
import pandas as pd
pertandingan= pd.read_csv("matches_data.csv", index_col=0)
print ("Banyak Data : ", pertandingan.shape[0])
print ("Total Kolom : ", pertandingan.shape[1])
print ("Ambil 10 data teratas")
pertandingan.head(10)
# Out:
# Banyak Data :  1389
# Total Kolom :  27
# Ambil 10 data teratas
#           date   time            comp         round  day venue result   gf  \
# 1   2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2   2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3   2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4   2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# 8   2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W  1.0
# 10  2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D  2.0
# 11  2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0
# 13  2021-10-23  17:30  Premier League   Matchweek 9  Sat  Away      W  4.0
# 15  2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      L  0.0
#
# ...

# %%
print("Total Pertandingan dari Setiap team")
pertandingan["team"].value_counts()
# Out:
# Total Pertandingan dari Setiap team
# West Ham United             72
# Brighton and Hove Albion    72
# Southampton                 72
# Manchester United           72
# Newcastle United            72
# Leeds United                71
# Arsenal                     71
# Manchester City             71
# Wolverhampton Wanderers     71
# Crystal Palace              71
# Tottenham Hotspur           71
# Burnley                     71
# Chelsea                     70
# Aston Villa                 70
# Leicester City              70
# Everton                     70
# Sheffield United            38
# West Bromwich Albion        38
# Liverpool                   38
# Fulham                      38
# Brentford                   34
# Norwich City                33
# Watford                     33
# Name: team, dtype: int64

# %% [markdown]
# Dilihat disini ada beberapa team yang hanya mendapatkan pertandingan dibawah 40 kali, hal ini dikarenakan
# mereka hanya mengikuti 1 musim saja diantara musim 2020 dan 2021
#
# Sebagai Contoh Pertandingan dari Fulham

# %%
pertandingan[pertandingan["team"]=="Fulham"]
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2020-09-12  12:30  Premier League   Matchweek 1  Sat  Home      L  0.0
# 2   2020-09-19  15:00  Premier League   Matchweek 2  Sat  Away      L  3.0
# 4   2020-09-28  17:45  Premier League   Matchweek 3  Mon  Home      L  0.0
# 6   2020-10-04  14:00  Premier League   Matchweek 4  Sun  Away      L  0.0
# 7   2020-10-18  12:00  Premier League   Matchweek 5  Sun  Away      D  1.0
# 8   2020-10-24  15:00  Premier League   Matchweek 6  Sat  Home      L  1.0
# 9   2020-11-02  17:30  Premier League   Matchweek 7  Mon  Home      W  2.0
# 10  2020-11-07  20:00  Premier League   Matchweek 8  Sat  Away      L  0.0
# 11  2020-11-22  12:00  Premier League   Matchweek 9  Sun  Home      L  2.0
# 12  2020-11-30  17:30  Premier League  Matchweek 10  Mon  Away      W  2.0
# 13  2020-12-05  15:00  Premier League  Matchweek 11  Sat  Away      L  0.0
# ...

# %% [markdown]
# Disini terlihat bahwa Fulham hanya memiliki data pertandingan pada musim 2020-2021 hal ini dikarenakan pada
# musim selanjutnya Fulham terdegradasi dari EPL sehingga tidak bisa mengikuti pertandingan dimusim selanjutnya

# %% [markdown]
# # Membersihkan data kosong

# %%
print("Malihat jenis data masing - masing kolom")
pertandingan.dtypes
# Out:
# Malihat jenis data masing - masing kolom
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
pertandingan["date"]=pd.to_datetime(pertandingan["date"])
pertandingan
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  match report  notes    sh   sot  dist   fk   pk  \
# ...

# %%
pertandingan.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %% [markdown]
# Dari keterangan ini terlihat bahwa kolom date sudah terubah menjadi tipe data datetime yang mana nantinya
# akan berguna dalam proses selanjutnya. karena pada machine learning nantinya tidak dapat mengolah tipe data
# object

# %% [markdown]
# # Membuat Acuan
# ## Menambahkan Kolom yang berisi informasi berguna nantinya
#
# Menambahkan kolom kode_lokasi yang berfungsi untuk mengubah jenis data dari kolom venue kedalam integer dengan pengkodean 0 untuk away, dan 1 untuk home

# %%
pertandingan["kode_lokasi"]=pertandingan["venue"].astype("category").cat.codes
pertandingan
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# ...

# %% [markdown]
# Menambahkan kolom kode_team untuk mengubah data nama team menjadi pengkodean angka sehingga dapat diproses dalam machine learning nantinya

# %%
pertandingan["kode_team"]=pertandingan["opponent"].astype("category").cat.codes
pertandingan
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...    sh   sot  dist   fk   pk pkatt season  \
# ...

# %% [markdown]
# Menambahkan kolom jam dari kolom time menjadi angka, untuk menjadi salah satu acuan nantinya apabila misal suatu team bermain bagus di jam tertentu

# %%
pertandingan["jam"]= pertandingan["time"].str.replace(":.+", "", regex=True).astype("int")
pertandingan
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...   sot  dist   fk   pk pkatt season  \
# ...

# %% [markdown]
# Menambahkan kolom hari untuk mengubah kolom day menjadi pengkodean angka

# %%
pertandingan["hari"]=pertandingan["date"].dt.dayofweek
pertandingan
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  dist   fk   pk  pkatt season              team  \
# ...

# %% [markdown]
# Menambahkan Kolom target yang berfungsi menjadi acuan utama, di mana dalam kolom ini berisikan hasil pertandingan yang ada, apabila menang akan berisi 1 jika kalah atau seimbang akan berisi 0 (Karena kita akan memprediksi team yang menang nantinya)

# %%
pertandingan["target"]=(pertandingan["result"]=="W").astype("int")
pertandingan
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...   fk   pk  pkatt  season              team  \
# ...

# %% [markdown]
# # Melakukan Training data (Random Forest)

# %%
# !pip install scikit-learn

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Menginisiasi Fungsi

# %%
rf= RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %% [markdown]
# Membagi data ke dalam 2 (train, test), serta menginisiasi acuan yang digunakan

# %%
train=pertandingan[pertandingan["date"] < '2022-01-01']
test=pertandingan[pertandingan["date"] > '2022-01-01']
acuan=["kode_lokasi", "kode_team", "jam", "hari"]

# %% [markdown]
# membuat fungsi untuk melatih

# %%
rf.fit(train[acuan], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
prediksi = rf.predict(test[acuan])

# %% [markdown]
# # Melihat Akurasi dari model

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(test["target"], prediksi)
acc
# Out:
# 0.6123188405797102

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=prediksi))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           141  31
# 1            76  28

# %% [markdown]
# Dari olahan ini terlihat bahwa :
#
# - Akurasi data kita sebesar = 0.6123188405797102
# - Berdasarkan data tersebut terlihat pada saat kita memprediksi tim yang kalah ataupun seimbang kita memperoleh hasil yang bagus yaitu 141 benar dan 76 salah
# - Akan tetapi untuk memprediksi tim yang menang kita memperoleh hasil yang kurang memuaskan yaitu 31 salah dan 28 benar
#
# Sehingga kita harus merevisi akurasi kita menggunakan metode lainnya

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], prediksi)
# Out:
# 0.4745762711864407

# %% [markdown]
# Dari penghitungan akurasi selanjutnya terlihat bahwa akurasi kita hanya 0.4745762711864407 sehingga sesuai dengan data, bahwa machine kita kurang akurat dalam memprediksi

# %% [markdown]
# # Meningkatkan akurasi dengan Rolling Averages
#
# ### Membagi data set menjadi beberapa data set tergantung team

# %%
group_pertandingan= pertandingan.groupby("team")

# %%
print("Melihat Permainan Manchester City")
group=group_pertandingan.get_group("Manchester City")
group
# Out:
# Melihat Permainan Manchester City
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 54 2021-05-01  12:30  Premier League  Matchweek 34  Sat  Away      W  2.0
# 56 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Home      L  1.0
# 57 2021-05-14  20:00  Premier League  Matchweek 36  Fri  Away      W  4.0
# 58 2021-05-18  19:00  Premier League  Matchweek 37  Tue  Away      L  2.0
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  5.0
#
# ...

# %% [markdown]
# Dalam penggunaan metode Rolling Averages data akan menggunakan hasil dari pertandingan sebelumnya apakah tim tersebut menang atau kalah dan apa yang terjadi dalam pertandingan sebelumnya(3 Pertandingan) yang nantinya akan diolah ke dalam algoritma

# %%
def rolling_averages(group, cols, new_col):
    group=group.sort_values("date")
    rolling_stats=group[cols].rolling(3, closed='left').mean()
    group[new_cols]= rolling_stats
    group=group.dropna(subset=new_cols)
    return group

# %%
cols=["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols=[f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
#
#      ga        opponent  ...  hari  target  gf_rolling  ga_rolling sh_rolling  \
# ...

# %%
pertandingan_rolling = pertandingan.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
pertandingan_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Premier League  Matchweek 29
#                         33 2022-03-18  20:00  Premier League  Matchweek 30
#                         34 2022-04-02  15:00  Premier League  Matchweek 31
#                         35 2022-04-08  20:00  Premier League  Matchweek 32
#                         36 2022-04-24  14:00  Premier League  Matchweek 34
#
# ...

# %%
pertandingan_rolling=pertandingan_rolling.droplevel("team")
pertandingan_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 32 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 33 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 34 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 35 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 36 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
#      ga         opponent  ...  hari  target  gf_rolling  ga_rolling  \
# ...

# %% [markdown]
# Menghapus Kolom tim agar lebih mudah dalam menghitung algoritma(Kalau tidak harus pakai 2 value)

# %%
pertandingan_rolling.index=range(pertandingan_rolling.shape[0])
pertandingan_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1312 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 1313 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 1314 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1315 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 1316 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
# ...

# %% [markdown]
# # Melatih ulang Kode

# %%
def buat_prediksi(data, acuan):
    train=data[data["date"] < '2022-01-01']
    test=data[data["date"] > '2022-01-01']
    rf.fit(train[acuan], train["target"])
    prediksi = rf.predict(test[acuan])
    combined=pd.DataFrame(dict(actual=test["target"], predicted=prediksi), index=test.index)
    precision = precision_score(test["target"], prediksi)
    return combined, precision

# %% [markdown]
# # Map

# %%
combined, precision = buat_prediksi(pertandingan_rolling, acuan+new_cols)

# %% [markdown]
# Melihat Akurasi yang baru

# %%
precision
# Out:
# 0.625

# %%
combined
# Out:
#       actual  predicted
# 55         0          0
# 56         1          0
# 57         1          0
# 58         1          1
# 59         1          1
# ...      ...        ...
# 1312       1          0
# 1313       0          0
# 1314       1          0
# 1315       0          0
# 1316       0          0
#
# [276 rows x 2 columns]

# %% [markdown]
# Disini kita belum bisa melihat ini adalah data dari tim mana
# untuk itu perlu dilakukan perubahan

# %%
combined = combined.merge(pertandingan_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team       opponent  \
# 55         0          0 2022-01-23                  Arsenal        Burnley
# 56         1          0 2022-02-10                  Arsenal         Wolves
# 57         1          0 2022-02-19                  Arsenal      Brentford
# 58         1          1 2022-02-24                  Arsenal         Wolves
# 59         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0          0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result
# 55        D
# 56        W
# 57        W
# 58        W
# ...

# %% [markdown]
# Dalam data ini terdapat 2 tim dimana ada yang menjadi team dan ada yang menjadi opponent untuk itu kita akan melakukan merge agar data lebih akurat.
#
# Akan tetapi dalam data tersebut nama team dan oppenent terkadang tidak sama untuk itu perlu dilakukan nomralize

# %%
class MissingDict(dict):
    __missing__ = lambda self, key : key

map_values = {"Brighton and Hove Albion": "Brighton", 
              "Manchester United": "Manchester Utd", 
              "Newcastle United": "Newcastle Utd", 
              "Tottenham Hotspur": "Tottenham", 
              "West Ham United": "West Ham", 
              "Wolverhampton Wanderers": "Wolves"
}
mapping=MissingDict(**map_values)

# %%
combined["tim_baru"]= combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team       opponent  \
# 55         0          0 2022-01-23                  Arsenal        Burnley
# 56         1          0 2022-02-10                  Arsenal         Wolves
# 57         1          0 2022-02-19                  Arsenal      Brentford
# 58         1          1 2022-02-24                  Arsenal         Wolves
# 59         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0          0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result tim_baru
# 55        D  Arsenal
# 56        W  Arsenal
# ...

# %%
merged=combined.merge(combined, left_on=["date", "tim_baru"], right_on=["date", "opponent"])
merged
# Out:
#      actual_x  predicted_x       date                   team_x     opponent_x  \
# 0           0            0 2022-01-23                  Arsenal        Burnley
# 1           1            0 2022-02-10                  Arsenal         Wolves
# 2           1            0 2022-02-19                  Arsenal      Brentford
# 3           1            1 2022-02-24                  Arsenal         Wolves
# 4           1            1 2022-03-06                  Arsenal        Watford
# ..        ...          ...        ...                      ...            ...
# 257         1            0 2022-03-13  Wolverhampton Wanderers        Everton
# 258         0            0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 259         1            0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 260         0            0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 261         0            0 2022-04-24  Wolverhampton Wanderers        Burnley
#
# ...

# %%
print ("Akurasi = ", 27/40)
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# Akurasi =  0.675
# 1    27
# 0    13
# Name: actual_x, dtype: int64

# %%
hasil_prediksi=merged.rename(columns = { 
    "tim_baru_x":"Tim",
    "opponent_x":"Lawan",
    "result_x":"Prediksi"
})
hasil_prediksi=hasil_prediksi[["date","Tim", "Lawan", "Prediksi"]]
hasil_prediksi
# Out:
#           date      Tim          Lawan Prediksi
# 0   2022-01-23  Arsenal        Burnley        D
# 1   2022-02-10  Arsenal         Wolves        W
# 2   2022-02-19  Arsenal      Brentford        W
# 3   2022-02-24  Arsenal         Wolves        W
# 4   2022-03-06  Arsenal        Watford        W
# ..         ...      ...            ...      ...
# 257 2022-03-13   Wolves        Everton        W
# 258 2022-03-18   Wolves   Leeds United        L
# 259 2022-04-02   Wolves    Aston Villa        W
# 260 2022-04-08   Wolves  Newcastle Utd        L
# 261 2022-04-24   Wolves        Burnley        L
#
# [262 rows x 4 columns]

# %%
hasil_prediksi.to_csv('prediksi.csv',sep=',')

# %%
dprediksi = pd.read_csv("prediksi.csv", index_col=0)
dprediksi
# Out:
#            date      Tim          Lawan Prediksi
# 0    2022-01-23  Arsenal        Burnley        D
# 1    2022-02-10  Arsenal         Wolves        W
# 2    2022-02-19  Arsenal      Brentford        W
# 3    2022-02-24  Arsenal         Wolves        W
# 4    2022-03-06  Arsenal        Watford        W
# ..          ...      ...            ...      ...
# 257  2022-03-13   Wolves        Everton        W
# 258  2022-03-18   Wolves   Leeds United        L
# 259  2022-04-02   Wolves    Aston Villa        W
# 260  2022-04-08   Wolves  Newcastle Utd        L
# 261  2022-04-24   Wolves        Burnley        L
#
# [262 rows x 4 columns]

# %%
dprediksi[(dprediksi["Tim"] == "Manchester City") & (dprediksi["Lawan"]=="Chelsea")]
# Out:
#            date              Tim    Lawan Prediksi
# 136  2022-01-15  Manchester City  Chelsea        W
